# %%
#Importing libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

#TO READ X AND Y AND ASSIGN IT TO X AND Y 
dataset=pd.read_csv('Data.csv')
X=dataset.iloc[:,:-1].values
y=dataset.iloc[:,3].values

#TO FILL EMPTY COLUMNS
from sklearn.preprocessing import Imputer,LabelEncoder,OneHotEncoder
imputer=Imputer(missing_values='NaN',strategy='mean',axis=0)
imputer=imputer.fit(X[:,1:3])
X[:,1:3]=imputer.transform(X[:,1:3])

#TO CONVERT CATEGORICAL DATA
labelencoder_X=LabelEncoder()
X[:,0]=labelencoder_X.fit_transform(X[:,0])
onehotencoder=OneHotEncoder(categorical_features=[0])
X=onehotencoder.fit_transform(X).toarray()

#TO SPLIT THE DATA
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

#Feature scaling
from sklearn.preprocessing import StandardScaler
sc_x=StandardScaler()
X_train=sc_x.fit_transform(X_train)
# remember youtube video y we must do mean nd sd must be related to X train 
X_test=sc_x.transform(X_test)
sc_y=StandardScaler()
y_train=sc_y.fit_transform(y_train)


#Building Regression  model
 #regression model

#Predicting the values using polynomial regression
y_pred=regressor.predict(X)

#Visuallling polynomial data
plt.scatter(X,Y,color='red')
plt.plot(X,regressor.predict(X),color='blue')
plt.title("Polynomial regression")
plt.xlabel('Position level')
plt.ylabel('salary')

# To get higher resolution of the graph plotted
X_grid=np.arange(min(X),max(X),0.1)
X_grid=X_grid.reshape((len(X_grid),1))
plt.scatter(X,Y,color='red')
plt.plot(X_grid,regressor.predict(X_grid),color='blue')
plt.title("Polynomial regression")
plt.xlabel('Position level')
plt.ylabel('salary')
